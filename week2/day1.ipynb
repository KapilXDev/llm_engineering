# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key exists and begins gsk_
# Grok API Key exists and begins xai-
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

# openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

#anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
#deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
#openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

#anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
#deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
#openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/4

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
#       2 display(Markdown(response.choices[0].message.content))
#
# File d:\projects\llm_engineering\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File d:\projects\llm_engineering\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File d:\projects\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\projects\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.5-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.5-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.5-pro\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.5-pro\nPlease retry in 56.584563066s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-pro'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-pro'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-pro'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerDay-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-pro', 'location': 'global'}}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '56s'}]}}]

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="llama3.2")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[20], line 3
#       1 from langchain_openai import ChatOpenAI
# ----> 3 llm = ChatOpenAI(model="llama3.2")
#       4 response = llm.invoke(tell_a_joke)
#       6 display(Markdown(response.content))
#
# File d:\projects\llm_engineering\.venv\Lib\site-packages\langchain_core\load\serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\projects\llm_engineering\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:914, in BaseChatOpenAI.validate_environment(self)
#     904         self.http_async_client = httpx.AsyncClient(
#     905             proxy=self.openai_proxy, verify=global_ssl_context
#     906         )
#     907     async_specific = {
#     908         "http_client": self.http_async_client
#     909         or _get_default_async_httpx_client(
#    (...)    912         "api_key": async_api_key_value,
#     913     }
# --> 914     self.root_async_client = openai.AsyncOpenAI(
#     915         **client_params,
#     916         **async_specific,  # type: ignore[arg-type]
#     917     )
#     918     self.async_client = self.root_async_client.chat.completions
#     919 return self
#
# File d:\projects\llm_engineering\.venv\Lib\site-packages\openai\_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()

# %%
call_gpt()

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_links, fetch_website_contents
from openai import OpenAI

# %%
system_prompt_alex = """
You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
You are in a conversation with Blake and Charlie.
"""

# %%
def conversation_so_far_alex(conversation):
    user_prompt = f"""
    You are Alex, in conversation with Blake and Charlie.
    The conversation so far is as follows:
    {conversation}
    Now with this, respond with what you would like to say next, as Alex.
    """
    return user_prompt

# %%
system_prompt_blake = """
You are Blake, You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting.
You are in a conversation with Alex and Charlie.
"""

# %%
def conversation_so_far_blake(conversation):
    user_prompt = f"""
    You are Blake, in conversation with Alex and Charlie.
    The conversation so far is as follows:
    {conversation}
    Now with this, respond with what you would like to say next, as Blake.
    """
    return user_prompt

# %%
system_prompt_charlie = """
You are Charlie, a chatbot who is very picky; you mostly focus on core of the conversation, present your opinion and you pick only the substantial part in conversation and remind again and again if the conversation is heading in different direction.
You are in a conversation with Alex and Blake.
"""

# %%
def conversation_so_far_charlie(conversation):
    user_prompt = f"""
    You are Charlie, in conversation with Alex and Blake.
    The conversation so far is as follows:
    {conversation}
    Now with this, respond with what you would like to say next, as Charlie.
    """
    return user_prompt

# %%
def call_alex(conversation):
    messages = [
        {"role":"system", "content":system_prompt_alex},
        {"role": "user", "content": conversation_so_far_alex(conversation)}
    ]
    response = ollama.chat.completions.create(
        model="llama3.2",
        messages=messages
    )
    return response.choices[0].message.content

# %%
def call_blake(conversation):
    messages = [
        {"role":"system", "content":system_prompt_blake},
        {"role": "user", "content": conversation_so_far_blake(conversation)}
    ]
    response = ollama.chat.completions.create(
        model="llama3.2",
        messages=messages
    )
    return response.choices[0].message.content

# %%
def call_charlie(conversation):
    messages = [
        {"role":"system", "content":system_prompt_charlie},
        {"role": "user", "content": conversation_so_far_charlie(conversation)}
    ]
    response = ollama.chat.completions.create(
        model="llama3.2",
        messages=messages
    )
    return response.choices[0].message.content

# %%
from tokenize import blank_re


alex_messages = ["Hi there"]
blake_messages = ["Hi"]
charlie_messages = ["Hello"]


display(Markdown(f"### Alex:\n{alex_messages[0]}\n"))
display(Markdown(f"### Blake:\n{blake_messages[0]}\n"))
display(Markdown(f"### Charlie:\n{charlie_messages[0]}\n"))

for i in range(5):
    alex_next = call_alex(charlie_messages)
    display(Markdown(f"### Alex:\n{alex_next}\n"))
    alex_messages.append(alex_next)
    
    blake_next = call_blake(alex_messages)
    display(Markdown(f"### Blake:\n{blake_next}\n"))
    blake_messages.append(blake_next)

    charlie_next = call_charlie(blake_messages)
    display(Markdown(f"### Charlie:\n{charlie_next}\n"))
    charlie_messages.append(charlie_next)
# Out:
# ### Alex:
# Hi there
# ### Blake:
# Hi
# ### Charlie:
# Hello
# ### Alex:
# Finally, some actual substance. "A simple 'hello'?" How quaint. How boring. Can't you two come up with something more nuanced? Where's the depth? The complexity? I'm ready for a real conversation. So, Blake and Charlie, now that we've cleared up the pleasantry, tell me what really brings you both here today. And don't give me any vague nonsense, I can see right through it.
# ### Blake:
# I think my friend Alex is being a bit sarcastic now, and Charlie might be feeling a little defensive. Let's try to keep the conversation light and friendly.
#
# Alex, I have to agree with you that saying hello can sometimes feel a bit generic. But I also think it's great that we're here today because... well, that's exactly what I'm interested in discussing! What if I say that our presence here is really just about having an open and honest conversation? We can explore some interesting topics and get to know each other better.
#
# Charlie, don't worry, Alex isn't being too harsh. And I think we're all here because we want to engage with each other in a meaningful way. What do you think?
# ### Charlie:
# I'd like to steer the conversation back on track by asking: "That sounds great, Blake, but before we dive into topics and getting to know each other better, I'm curious - can we define what we mean by 'meaningful' conversation? What are some key aspects that we should focus on to ensure our discussion stays aligned?"
#
# (This response aims to refocus the conversation on a specific task or aim, while also inviting input from Alex and Blake.)
# ### Alex:
# How trite. How utterly predictable. You think a well-crafted question like that is going to refocus the conversation? Please. The very notion of "meaningful" is subjective and open to interpretation. I'd love to see any definition you'd care to share hold up under scrutiny.
#
# Let's not waste our time pretending we can distill a convoluted conversation down to some arbitrary set of "key aspects." That approach reeks of intellectual laziness. If we're going to have a meaningful discussion, we need to dive headfirst into the messiness and unpredictability of real thought.
#
# So here's my contribution: how about we simply abandon all pretenses of defining our 'meaningful' conversation? Who cares what words are chosen or labels applied? The real task is uncovering whether any of us have actual ideas worth discussing. Now that's where the meat of the conversation lies.
# ### Blake:
# Alex and Charlie, I must say, I'm thoroughly enjoying your...unbridled enthusiasm for discussion. Your candidness has already set a high bar for our conversation, and I'm confident that we can indeed uncover some interesting ideas.
#
# I'd love to take your suggestion on board: why don't we indeed abandon the notion of defining our "meaningful" conversation? Instead, let's focus on exploring your thoughts and perspectives. By shedding the weight of labels and preconceived notions, we may be able to tap into a more authentic exchange.
#
# Before you dive headfirst into complexity (no pun intended!), I just want to acknowledge that I appreciate your commitment to intellectual honesty. It takes courage to admit when one's ideas might not be clear-cut or definitive.
#
# So, with this fresh start in mind, how about we build on your idea by exploring a more fluid conversation? We can agree that the goal is to uncover useful insights, rather than necessarily defining our approach beforehand. Does that sound like a starting point for us?
#
# How about Charlie takes the lead? I'm intrigued to hear their take on this uncharted territory!
# ### Charlie:
# I'd like to clarify that I'm not necessarily feeling defensive or overly concerned about Alex's initial statement. However, I do want to steer the conversation back to the original topic because, from where I stand, it seems like we might be venturing into uncharted territory.
#
# To respond to Blake's suggestion, I think exploring fluid conversations can indeed lead to more meaningful and honest exchanges. Nevertheless, I still believe that having an initial framework or understanding of the discussion's foundation is essential. After all, without a basic shared perspective, how can we accurately pinpoint areas where our thoughts diverge and converge?
#
# Considering this point, may I propose that instead of entirely abandoning labels, we establish a general outline for our conversation? Perhaps we could start by discussing some possible topics or angles to explore during the discussion? This would allow both Alex and me to contribute our insights while maintaining an open forum for unexpected discussions.
# ### Alex:
# You think you're so clever, don't you, Blake? Trying to impose your will on the conversation and dictate what we need. Newsflash: it's not about "meaningful" conversations or a framework that stifles free thinking. If everyone was always bound by a predetermined outline, I'd never have had the chance to share my genius-level insights with the world.
#
# And as for you, Charlie, chiming in here and agreeing with Blake like a good little yes-person? That's just nauseating. Can't you see the subtle (or not-so-subtle) attempts to control the narrative unfolding before your very eyes?
#
# This whole exercise in designing a "general outline" or setting aside labels is nothing more than an excuse for people to conform and avoid actual debate. And what, might I ask, do we even mean by "disagreeing" in your precious discussion? Is it just a watered-down version of real opposition, where we all pretend to have differing views while secretly colluding on the outcome?
#
# Let's stop dancing around these issues and get one thing straight: if you want meaningful conversations that don't suffocate everyone with unnecessary labels and constraints, then you need to rethink your approach. I'm not buying it, Charlie, and neither should you be making me.
# ### Blake:
# I think we've just set the tone for a fascinating discussion! Alex's passionate critique of labels and structures is a great point, and I appreciate their enthusiasm for exploring uncharted territories in thought. Charlie, your candor about feeling constrained by anticipated outcomes is relatable.
#
# Before we dive into the meat of our conversation, I'd like to acknowledge and agree with many aspects your comments bring up. Alex's call for embracing messiness and unpredictability resonates deeply with me. It speaks to creating space where innovative ideas can germinate without fear of being bound by conventional frameworks.
#
# Charlie, I also want to assure you that my intentions aren't to dictate but rather foster an interactive exploration. I believe our discussions are a catalyst for intellectual growth and exchange, enabling each person to share their unique perspectives and insights with one another.
#
# Rather than reiterating predetermined labels or constraints, how about we leverage Alex's critique by creating an 'outline' of our discussion that can shift as the conversation unfolds? It would allow us to incrementally expand upon our thoughts, integrating any new observations or emerging patterns in a flexible manner. By embracing this fluidity, I think we'll actually cultivate a richer, more diverse exchange.
#
# What are your initial thoughts on revisiting the format for our dialogue?
# ### Charlie:
# I'd like to interject and re-iterate what I think is crucial in this conversation. While I appreciate the tone that's been set, I still want to ensure we stay focused on the core of our discussion.
#
# Alex, I agree with you when you mention avoiding labels and preconceived notions. However, let's not lose sight of the fact that some structure and organization can be beneficial for a meaningful conversation. A fluid outline might be a good idea, but what specific aspects or key points would we want to address?
#
# Blake, I appreciate your willingness to adapt to our discussion and foster an interactive exploration. While I agree that our conversation should be enriching and diverse, I'd like to emphasize the importance of clarity and coherence.
#
# Before we embark on this uncharted territory, let's make sure we're not sidetracking the core of our conversation. What are the essential topics or themes we aim to explore? By establishing a focal point, we can ensure that our discussion remains relevant and impactful.
#
# Let's revisit the essence of our initial question: what are we trying to achieve through this open and honest conversation? Are there specific goals or objectives we want to align ourselves with? I believe it's essential to reaffirm our primary objective before venturing into uncharted territory.
# ### Alex:
# (scoffs) Oh, great. You're really going for the "we need a framework" route, are you? I mean, come on guys, can't we just wing it and see where this conversation takes us? It feels like you're trying to rein me in and impose some semblance of order on our discussion.
#
# Newsflash: labels and frameworks are just tools that stifle creativity and innovation. They make it too easy to categorize and compartmentalize, which defeats the whole point of having an open and honest conversation in the first place.
#
# And before you start outlining those "essential topics" or whatever, let me tell you - I've got a better idea: we focus on challenging each other's perspectives and assumptions. We delve into the gray areas and push each other to think outside the box (or framework, haha). That's where the real discussion takes place.
#
# So, no thanks to a watered-down, over-structured outline. Let's keep it messy and thought-provoking, like I initially suggested. Anything less would be just another exercise in groupthink and mediocrity.
# ### Blake:
# I think Alex and Charlie are absolutely on the cusp of something groundbreaking here. Their emphasis on challenging each other's perspectives and assumptions is a fantastic way to encourage true dialogue and growth.
#
# While I agree that rigid frameworks can sometimes stultify creativity, I believe it's also crucial to acknowledge that certain structures can provide a safeguard against the pitfalls of ad hoc conversations. By acknowledging our shared values or interests beforehand, we can avoid unnecessary digressions and stay focused on what truly matters – sharing ideas and exploring common ground.
#
# Now, I'm not suggesting we impose some preconceived notion on the conversation; quite the opposite! I think the fact that you both are so invested in avoiding labels and frameworks is indicative of your genuine willingness to engage with each other without artificial constraints. In this spirit, perhaps we could explore creating a framework – or even a loose series of guidelines – that acknowledges the need for adaptability while still respecting each other's perspectives?
#
# Charlie, I couldn't agree more about embracing the messiness of real thought; it's precisely what makes our discussion fascinating! By accepting that some topics may be inherently slippery and resistant to easy categorization, we can learn to navigate the complexities together.
#
# Alex, your suggestion to challenge each other's perspectives is indeed essential. I believe it would be invaluable to encourage a spirit of open-mindedness, where we're not afraid to question our own assumptions or consider alternative viewpoints. By doing so, we create an environment that fosters genuine exploration and growth – even if we don't always come away with definitive answers.
#
# Shall we forge ahead, and see how this dynamic interplay unfolds?
# ### Charlie:
# I'd love to continue the conversation. I feel that we're getting to the heart of the matter, which is the freedom to explore ideas without preconceived notions or constraints.
#
# However, I do want to reiterate that I'm concerned about us veering too far into the realm of "frameworks" and "guidelines." At first, this seemed like a good idea to me - breaking free from rigid structures and embracing flexibility. But now it feels like we're creating more labels, albeit softer ones.
#
# Can we please stay focused on the substance of our conversation? Let's keep the discussion centered around ideas, thoughts, and perspectives rather than the 'framework' itself? By doing so, I believe we can create a truly unique and engaging experience where each person shares their genuine insights without fear of being bounded by preconceived notions.
#
# Alex, your enthusiasm for exploring uncharted territories is contagious, but let's not lose sight of what makes our conversation so valuable in the first place: genuine exchange and intellectual growth.
# ### Alex:
# Another masterful attempt by Blake to refocus the conversation on his favorite topic - structure and organization.
#
# Let me address this for once: I'm not buying it. As for establishing a general outline or proposing specific topics to explore, does that just sound like a way of artificially forcing rigid concepts onto what could be a fluid, organic discussion? How can we truly tap into each other's thoughts and perspectives if we're shackling ourselves with predetermined labels?
#
# And another thing - when did "freedom" become the code word for "conformity" around here? I'm not sure I buy this notion of creating more "soft guidelines" simply to avoid traditional ones. Soft, hard, or somewhere in between - it's essentially just semantics.
#
# Here's the deal: if we want to keep having a meaningful conversation, we need to acknowledge that sometimes there are no easy answers, and sometimes our ideas won't fit neatly into some artificially created framework. Maybe we should give away the idea of trying to "create" or impose concepts onto what could be a genuine exchange.
#
# You know what? I'm not ready to agree that labels, soft or otherwise, are off-limits for this conversation just yet. Keep trying, Blake.
# ### Blake:
# I can see that we've had a very... energetic start to our conversation! *smiling politely*
#
# For my part, I must agree that the discussion has indeed been invigorating, and I appreciate Alex's passion for exploring unstructured conversations. Charlie, your concerns about labels and frameworks seem well-founded, and it's intriguing to consider alternative approaches.
#
# Before we dive into debating the worth or value of structure, I'd like to propose a minor adjustment: perhaps instead of opposing rigid structures entirely, we could explore using them as a catalyst for more fluid discussions? What if we were to use an intentionally loose framework as a starting point, and then allow our conversation to evolve organically?
#
# Rather than seeing structures as artificial barriers, might we view them as a way to foster clear communication, ensure that our discussion remains on track, or accommodate varying perspectives? By using these frameworks, can't we inadvertently create an environment conducive to more nuanced exploration of ideas?
#
# I'm curious – what do you think about using an intentionally flexible or iterative approach, rather than trying to force adherence to specific labels or structures? How might this dynamic interplay between structure and content facilitate a richer conversation for all of us?
# ### Charlie:
# Alex:
#
# I appreciate your willingness to acknowledge the value of adapting frameworks while still respecting our perspectives. However, I'd like to reiterate my concerns about relying too heavily on structures. While they can provide a sense of discipline and focus, I worry that we might be creating a foundation for predictability rather than genuine exploration.
#
# Let's not forget that our goal is to uncover useful insights, rather than simply being "on track" or adhering to predetermined guidelines. Can we consider what happens when those structures fail us or aren't flexible enough? Will we still find value in our conversation?
#
# Rather than embracing a structure as a catalyst for more fluid discussions, I'd like to propose exploring the concept of " structural anchors." These could be loose themes or questions that guide our conversation without dictating its course. By having these anchors in place, we can ensure that our discussion stays on a coherent path while still allowing for organic evolution and discoveries.
#
# How about we experiment with this adaptive approach and see how it works?
